# %%
import pyforest

# %%
pip install pyforest
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pyforest: filename=pyforest-1.1.0-py2.py3-none-any.whl size=14632 sha256=2ec49f49648b8c001801200983e6688dc26fc2228ce0b084702dc64f7eb83552
#   Stored in directory: c:\users\jogip\appdata\local\pip\cache\wheels\99\7b\47\025a4475a5cefab0923fd7435aa03c83c8434b5ed351dac211
# Successfully built pyforest
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv("netflix.csv")

# %%
df
# Out:
#        show_id     type                                        title
# 0     81145628    Movie      Norm of the North: King Sized Adventure  \
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director
# 0     Richard Finn, Tim Maltby  \
# 1                          NaN
# 2                          NaN
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.head()
# Out:
#     show_id     type                                    title
# 0  81145628    Movie  Norm of the North: King Sized Adventure  \
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director
# 0  Richard Finn, Tim Maltby  \
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...  \
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
df.describe()
# Out:
#             show_id  release_year
# count  6.234000e+03    6234.00000
# mean   7.670368e+07    2013.35932
# std    1.094296e+07       8.81162
# min    2.477470e+05    1925.00000
# 25%    8.003580e+07    2013.00000
# 50%    8.016337e+07    2016.00000
# 75%    8.024489e+07    2018.00000
# max    8.123573e+07    2020.00000

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df_new=df.dropna()

# %%
df_new.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df_new.shape
# Out:
# (3774, 12)

# %%
df_new.nunique()
# Out:
# show_id         3774
# type               2
# title           3752
# director        2920
# cast            3667
# country          433
# date_added      1014
# release_year      69
# rating            14
# duration         184
# listed_in        296
# description     3766
# dtype: int64

# %%
df_new.head()
# Out:
#     show_id   type                                    title
# 0  81145628  Movie  Norm of the North: King Sized Adventure  \
# 4  80125979  Movie                             #realityhigh
# 6  70304989  Movie                                 Automata
# 7  80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 9  70304990  Movie                              Good People
#
#                           director
# 0         Richard Finn, Tim Maltby  \
# 4                 Fernando Lebrija
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
# 9                Henrik Ruben Genz
#
#                                                 cast
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...  \
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                    Fabrizio Copano
# 9  James Franco, Kate Hudson, Tom Wilkinson, Omar...
#
# ...

# %%
df_new.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df_new["date_added1"]=pd.to_datetime(df_new["date_added"],format="%B %d, %Y")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 df_new["date_added1"]=pd.to_datetime(df_new["date_added"],format="%B %d, %Y")
#
# File ~\ desktop\anaconda\lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~\ desktop\anaconda\lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# ...

# %%
df_new['date_added'] = pd.to_datetime(df_new['date_added'], errors='coerce')
incorrect_dates = df_new[df_new['date_added'].isna()]
# Out:
# C:\Users\jogip\AppData\Local\Temp\ipykernel_9392\275822065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['date_added'] = pd.to_datetime(df_new['date_added'], errors='coerce')

# %%
incorrect_dates
# Out:
#        show_id     type                                       title
# 5591  70197049  TV Show                            Once Upon a Time  \
# 5594  80020542  TV Show                                      Gotham
# 5633  70205012  TV Show                                      Naruto
# 5639  80108561  TV Show                             Toast of London
# 5666  70242310  TV Show                               Hemlock Grove
# 5756  80175619  TV Show                     Glitter Force Doki Doki
# 5764  80144355  TV Show                                        Mars
# 5787  70143825  TV Show                                Supernatural
# 5790  80066080  TV Show                    DC's Legends of Tomorrow
# 5792  80065386  TV Show                                   Supergirl
# 5799  80133311  TV Show                                   Riverdale
# 5800  80027042  TV Show                                   The Flash
# 5801  80018046  TV Show                                      Velvet
# ...

# %%
x=df_new.dropna()

# %%
x
# Out:
#        show_id   type                                    title
# 0     81145628  Movie  Norm of the North: King Sized Adventure  \
# 4     80125979  Movie                             #realityhigh
# 6     70304989  Movie                                 Automata
# 7     80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 9     70304990  Movie                              Good People
# ...        ...    ...                                      ...
# 5574  80104237  Movie                            The Tenth Man
# 5575  80093107  Movie                                     Toro
# 5578  80085439  Movie                          Frank and Cindy
# 5579  80011846  Movie                                  Iverson
# 5580  80064521  Movie      Jeremy Scott: The People's Designer
#
#                              director
# 0            Richard Finn, Tim Maltby  \
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# 7     Rodrigo Toro, Francisco Schultz
# ...

# %%
x.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
x.shape
# Out:
# (3743, 12)

# %%
x['day_added'] = x['date_added'].dt.day
x['year_added'] = x['date_added'].dt.year
x['month_added']=x['date_added'].dt.month
x['year_added'].astype(int);
x['day_added'].astype(int);
# Out:
# C:\Users\jogip\AppData\Local\Temp\ipykernel_9392\4236152184.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['day_added'] = x['date_added'].dt.day
# C:\Users\jogip\AppData\Local\Temp\ipykernel_9392\4236152184.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['year_added'] = x['date_added'].dt.year
# C:\Users\jogip\AppData\Local\Temp\ipykernel_9392\4236152184.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
x
# Out:
#        show_id   type                                    title
# 0     81145628  Movie  Norm of the North: King Sized Adventure  \
# 4     80125979  Movie                             #realityhigh
# 6     70304989  Movie                                 Automata
# 7     80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 9     70304990  Movie                              Good People
# ...        ...    ...                                      ...
# 5574  80104237  Movie                            The Tenth Man
# 5575  80093107  Movie                                     Toro
# 5578  80085439  Movie                          Frank and Cindy
# 5579  80011846  Movie                                  Iverson
# 5580  80064521  Movie      Jeremy Scott: The People's Designer
#
#                              director
# 0            Richard Finn, Tim Maltby  \
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# 7     Rodrigo Toro, Francisco Schultz
# ...

# %%
sns.countplot(x=x["type"])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Type')
# Out:
# Text(0.5, 1.0, 'Type')

# %% [markdown]
# # Relation between Type and Rating

# %%
sns.countplot(x=x['rating'])
fig.set_size_inches(13,13)

# %% [markdown]
# # Relation between rating and type

# %%
sns.countplot(x=x["rating"],hue=x["type"])
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %% [markdown]
# # pie chart for type

# %%
size = x['type'].value_counts()
plt.pie(size)
# Out:
# ([<matplotlib.patches.Wedge at 0x266b33d9060>,
# ...
#  [Text(-1.0983634021154192, 0.05998197140343131, ''),
#   Text(1.0983634014134294, -0.059981984257957234, '')])

# %%
labels = ['Movie', 'TV show']
size = x['type'].value_counts()
colors = plt.cm.Wistia(np.linspace(0, 1, 2))
explode = [0, 0.1]
plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size,labels=labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Distribution of Type', fontsize = 25)
plt.legend()
plt.show()

# %% [markdown]
# # pie chart for rating

# %%
x['rating'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(10,8))
# Out:
# <Axes: ylabel='count'>
